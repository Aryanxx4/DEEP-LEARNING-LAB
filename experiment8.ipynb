# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryanxx4/DEEP-LEARNING-LAB/blob/main/experiment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Embedding

# %%
vocab_size = 10000
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
max_len = 200
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=max_len))
model.add(Bidirectional(LSTM(64, return_sequences=False)))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)

# Evaluate
loss, accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 171s 532ms/step - accuracy: 0.7638 - loss: 0.4749 - val_accuracy: 0.8576 - val_loss: 0.3440
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 156s 500ms/step - accuracy: 0.8929 - loss: 0.2743 - val_accuracy: 0.8618 - val_loss: 0.3425
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 157s 501ms/step - accuracy: 0.9262 - loss: 0.1980 - val_accuracy: 0.8700 - val_loss: 0.3383
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 166s 530ms/step - accuracy: 0.9462 - loss: 0.1488 - val_accuracy: 0.8620 - val_loss: 0.3964
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 189s 487ms/step - accuracy: 0.9553 - loss: 0.1239 - val_accuracy: 0.8606 - val_loss: 0.3970
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.8590 - loss: 0.3987
# Test Accuracy: 0.8590400218963623

# %%
pred = model.predict(x_test[:10])
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# [[0.2765412 ]
#  [0.9996492 ]
#  [0.9451219 ]
#  [0.54944927]
#  [0.99996084]
#  [0.85445607]
#  [0.9974196 ]
#  [0.0225578 ]
#  [0.993146  ]
#  [0.996938  ]]
